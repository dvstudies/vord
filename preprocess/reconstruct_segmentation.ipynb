# %%
import pandas as pd
import re
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os
import shutil
import random
from PIL import Image
from scipy.sparse import bsr_matrix
from scipy import sparse

# %%
masks_folder = "data/npz/"
clip_folder = "data/npz_clip/"

df = pd.read_csv("data/omniart_CLIP_embeddings.csv")

# %%
fname = str(int(df['omni_id'][2000]))

# Reconstruct the 3D array of masks
loaded_data = bsr_matrix(sparse.load_npz(os.path.join(masks_folder,f'{fname}_sparse_masks.npz')))

segmented_img = loaded_data.toarray()
plt.imshow(segmented_img)
